# %%
# check scikit-learn version
import sklearn
print(sklearn.__version__)
# Out:
# 1.0

# %%
import pandas as pd
df   =   pd.read_csv( 'data_uci.csv' )

# %%
df
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
# ...

# %%
df['stabf'].unique()
# Out:
# array(['unstable', 'stable'], dtype=object)

# %%
from  sklearn.preprocessing import LabelEncoder 
label_encoder= LabelEncoder()
df['stabf']= label_encoder.fit_transform(df['stabf'])
df['stabf'].unique()
# Out:
# array([1, 0])

# %%
df
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
# ...

# %%
df.drop(columns='stab')
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4  stabf
# ...

# %%
x=df.drop(columns='stabf')
y=df['stabf']

# %%
#split the   data   into   training  and   testing  sets 
from   sklearn.model_selection import train_test_split 
x_train,  x_test,  y_train,  y_test  =   train_test_split(x, y,   test_size= 0.3 ,   random_state= 0 ) 
y_train.value_counts()
# Out:
# 1    4478
# 0    2522
# Name: stabf, dtype: int64

# %%
import imblearn
from imblearn.over_sampling import SMOTE 
smote  =   SMOTE(random_state= 1 ) 
x_train_balanced, y_balanced =smote.fit_resample(x_train, y_train)

# %%
y_balanced.value_counts()
# Out:
# 1    4478
# 0    4478
# Name: stabf, dtype: int64

# %%
from  sklearn.preprocessing import MinMaxScaler 
scaler   =  MinMaxScaler()

# %%
norm_train_df =   scaler.fit_transform(x_train_balanced) 
norm_test_df =   scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
Random_model=RandomForestClassifier(n_estimators=10, random_state=1)
Random_model.fit(norm_train_df,y_balanced)
randpred=Random_model.predict(norm_test_df)

# %%
from  sklearn.metrics import accuracy_score
accuracy  =   accuracy_score(y_test,randpred)

# %%
accuracy
# Out:
# 0.9996666666666667

# %%
from sklearn.ensemble import ExtraTreesClassifier
EXtreemodel=ExtraTreesClassifier(n_estimators=10, random_state=1)
EXtreemodel.fit(norm_train_df,y_balanced)
# Out:
# ExtraTreesClassifier(n_estimators=10, random_state=1)

# %%
from sklearn.model_selection import RandomizedSearchCV

n_estimators = [50, 100, 300, 500, 1000]

# Number of features to consider at every split
max_features = ['auto', 'sqrt', 'log2', None]


# Minimum number of samples required to split a node
min_samples_split = [2, 3, 5, 7, 9]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4, 6, 8]

# Create the hyperparameter_grid
hyperparameter_grid = {
               'max_features': max_features,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
                      }

model_tuned= RandomizedSearchCV(EXtreemodel,  param_distributions=hyperparameter_grid, random_state=1, cv=5, n_iter=10, scoring = 'accuracy', n_jobs = -1, verbose = 1)
dd=model_tuned.fit(norm_train_df,y_balanced)
dd.best_params_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None}
