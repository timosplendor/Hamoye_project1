# %%
url = 'https://bit.ly/HDSC-StageOneDataset'

import pandas as pd

data_set = pd.read_csv(url)
data_set
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
data_set.tail(20)
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 29503  f1_fuel_2018_12_191_1_14               191         2018
# 29504  f1_fuel_2018_12_191_1_15               191         2018
# 29505   f1_fuel_2018_12_432_0_2               432         2018
# 29506   f1_fuel_2018_12_432_0_5               432         2018
# 29507   f1_fuel_2018_12_432_0_8               432         2018
# 29508  f1_fuel_2018_12_432_0_11               432         2018
# 29509  f1_fuel_2018_12_432_0_14               432         2018
# 29510   f1_fuel_2018_12_403_0_2               403         2018
# 29511   f1_fuel_2018_12_403_0_6               403         2018
# 29512   f1_fuel_2018_12_403_0_9               403         2018
# 29513    f1_fuel_2018_12_12_0_2                12         2018
# 29514    f1_fuel_2018_12_12_0_4                12         2018
# 29515    f1_fuel_2018_12_12_0_7                12         2018
# 29516    f1_fuel_2018_12_12_0_8                12         2018
# ...

# %%
data_set.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %%
data_set.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
data_set1= data_set[['fuel_unit']].fillna(value='mcf')
data_set1.isnull().sum()
# Out:
# fuel_unit    0
# dtype: int64

# %%
ddata= data_set[0:1900].reset_index(drop='true')
sdata=  data_set[1900:].reset_index(drop='true')

mdat= pd.merge(ddata,sdata, how = "inner")
rdat= pd.merge(ddata,sdata, how = "outer")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(x='fuel_cost_per_unit_burned', y= 'fuel_gty_burned')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-dab8b7549cfa> in <module>
# ----> 1 sns.boxplot(x='fuel_cost_per_unit_burned', y= 'fuel_gty_burned')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2228 ):
#    2229
# -> 2230     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2231                           orient, color, palette, saturation,
#    2232                           width, dodge, fliersize, linewidth)
#
# ...
